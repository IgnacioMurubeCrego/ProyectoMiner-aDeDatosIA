# %% [markdown]
# # Income Census DataSet

# %%
import pandas as pd

from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
atributos = [
    "age",
    "workclass",
    "fnlwgt",
    "education",
    "education-num",
    "marital-status",
    "occupation",
    "relationship",
    "race",
    "sex",
    "capital-gain",
    "capital-loss",
    "hours-per-week",
    "native-country",
    "<50k/year"
]

# %%
df = pd.read_csv("/content/Income Census DataSet/adultData.csv",names=atributos, header=None, delimiter=";",skipinitialspace=False);
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.count()
# Out:
# age               32561
# workclass         32561
# fnlwgt            32561
# education         32561
# education-num     32561
# marital-status    32561
# occupation        32561
# relationship      32561
# race              32561
# sex               32561
# capital-gain      32561
# capital-loss      32561
# hours-per-week    32561
# native-country    32561
# <50k/year         32561
# dtype: int64

# %%
df_capital_gain = df['capital-gain']
df_capital_gain = df_capital_gain.dropna()
df_capital_gain.shape, df_capital_gain.count()
# Out:
# ((32561,), 32561)

# %%
plt.boxplot(df_capital_gain)
plt.show()

# %%
threshold_value = df_not_missing['capital-gain'].mean() + 3*df_not_missing['capital-gain'].std()

outliers = df_not_missing[df_not_missing['Hallux'] > threshold_value]

outliers

# %%
df_eeuu = df[df['native-country'] == "United-States"]
df["capital-gain"].value_counts()
# Out:
# capital-gain
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 1111         1
# 2538         1
# 22040        1
# 4931         1
# 5060         1
# Name: count, Length: 119, dtype: int64

# %%
df_subset = df.loc[:,["age","education-num","hours-per-week"]]
df_subset
# Out:
#        age  education-num  hours-per-week
# 0       39             13              40
# 1       50             13              13
# 2       38              9              40
# 3       53              7              40
# 4       28             13              40
# ...    ...            ...             ...
# 32556   27             12              38
# 32557   40              9              40
# 32558   58              9              40
# 32559   22              9              20
# 32560   52              9              40
#
# [32561 rows x 3 columns]
